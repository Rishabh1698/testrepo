# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
industry= pd.read_csv('Industry.csv')
city= pd.read_csv('City.csv')
exp= pd.read_csv('Experience.csv')

# %%
industry.head(15)
# Out:
#                                    Industry  Mar-22  Apr-22  May-22  June-22  \
# 0                                 Insurance    1541    1553    1946     1761
# 1        Banking/Financial Services/Broking    3138    3348    3299     3279
# 2   Oil and Gas/Power/Infrastructure/Energy     449     522     517      491
# 3                     Real Estate/ Property    3171    3316    3180     3083
# 4                       Auto/Auto Ancillary    1038    1146    1152     1106
# 5                       FMCG/Foods/Beverage    1842    1996    1960     1976
# 6                               Telecom/ISP     563     607     669      622
# 7                      Travel & Hospitality    1698    1609    1603     1468
# 8          Pharma/Biotech/Clinical Research    2117    2108    2078     1908
# 9               Medical/Healthcare/Hospital    6248    6323    6403     5983
# 10               BPO/ITES/CRM/Transcription    2458    2659    2617     2600
# ...

# %% [markdown]
# - Insurance and Banking sectors experiencing robust job creation.
# - Insurance sector saw remarkable 108% YoY growth in new jobs, driven by insurance product sales.
# - Banking sector grew by 45% YoY, attributed to expanding digital banking in the global economy.
# - IT sector contracted, with 17% decline in new job creation, noticeable in major IT companies.
# - Non-tech sectors - Oil, Real Estate, FMCG, Hospitality - grew by 35%, 31%, 14%, and 7% respectively from last year.
# - Retail, education, and BPO displayed caution with 4%, 2%, and 2% declines in hiring.

# %%
city.head(10)
# Out:
#                        City  Mar-22  Apr-22  May-22  Jun-22  Jul-22  Aug-22  \
# 0                    Mumbai    2029    2100    2188    2219    2338    2150
# 1               Delhi / NCR    2776    2811    2782    2792    3038    2604
# 2                   Chennai    2414    2364    2394    2432    2745    2519
# 3                      Pune    4012    4025    4114    4143    5035    4073
# 4                   Kolkata    3573    3486    3750    3760    4317    3773
# 5  Hyderabad / Secunderabad    4118    4097    3967    3907    4578    3812
# 6     Bengaluru / Bangalore    3701    3532    3484    3722    4076    3420
# 7         Vadodara / Baroda    2516    2798    2872    2702    2881    2512
# 8                 Ahmedabad    4041    4235    4438    4598    5344    5110
# 9                    Jaipur    3831    4435    4206    4272    4282    4632
#
#    Sep-22  Oct-22  Nov-22  Dec-22  Jan-23  Feb-23  Mar-23 Growth %
# ...

# %% [markdown]
# - Year-on-Year (YoY) job creation trends in several cities. Mumbai showed steady growth with a 17% increase. Delhi/NCR had a moderate 7% growth, while Chennai's growth was modest at 3%. Pune experienced a slight decline of -2%, and Kolkata had a marginal decrease of -1%. Hyderabad faced a notable drop of -11%, and Bangalore experienced a significant -12% decline. Vadodara displayed a remarkable +50% surge, while Ahmedabad's growth was strong at +49%. Jaipur showcased notable expansion with a 29% increase. Overall, cities like Vadodara, Ahmedabad, and Jaipur demonstrated robust growth, while other cities faced mixed trends in job creation.

# %%
exp.head()
# Out:
#   Experience  Mar-22  Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  Oct-22  \
# 0    0-3 yrs    3154    3223    3170    3105    3266    2999    3265    2642
# 1    4-7 yrs    3018    3067    3067    3072    3386    3053    3346    2632
# 2   8-12 yrs    2505    2494    2557    2663    3093    2644    2914    2229
# 3  13-16 yrs    1922    1854    1885    2008    2298    1928    2178    1771
# 4   16 + yrs    1762    1713    1695    1722    2013    1693    1946    1613
#
#    Nov-22  Dec-22  Jan-23  Feb-23  Mar-23  Growth %
# 0    3253    3106    2926    3073    3144      0.00
# 1    3293    2998    2871    3104    3010      0.00
# 2    2864    2676    2568    2885    2859      0.14
# 3    2342    2231    2159    2362    2389      0.24
# 4    2055    2184    2051    2273    2373      0.35

# %% [markdown]
# - 0-3 yrs (Entry Level): Job opportunities for individuals with 0-3 years of experience remained relatively consistent throughout the year. The YoY growth was stable at 0%, reflecting a steady state in employment prospects for those entering the job market.
#
# - 4-7 yrs (Early Career): Early career professionals in the 4-7 years experience bracket saw similar trends, with consistent employment opportunities. The YoY growth was also steady at 0%, indicating a balanced job market for this experience level.
#
# - 8-12 yrs (Mid-Career): Mid-career professionals with 8-12 years of experience experienced a slight upward trajectory in job creation. The YoY growth reached 0.14%, suggesting a gradual increase in employment opportunities for this experience group.
#
# - 13-16 yrs (Experienced): Professionals with 13-16 years of experience witnessed a moderate growth in job opportunities. The YoY growth was 0.24%, indicating a positive trend in the employment landscape for individuals in this experience range.
#
# - 16+ yrs (Senior Level): Senior-level professionals with 16+ years of experience saw consistent growth in job creation. The YoY growth reached 0.35%, highlighting a steady expansion in employment opportunities for those at the senior end of the experience spectrum.

# %%
industry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Industry  14 non-null     object
#  1   Mar-22    14 non-null     int64
#  2   Apr-22    14 non-null     int64
#  3   May-22    14 non-null     int64
#  4   June-22   14 non-null     int64
#  5   July-22   14 non-null     int64
#  6   Aug-22    14 non-null     int64
#  7   Sep-22    14 non-null     int64
#  8   Oct-22    14 non-null     int64
#  9   Nov-22    14 non-null     int64
#  10  Dec-22    14 non-null     int64
#  11  Jan-23    14 non-null     int64
#  12  Feb-23    14 non-null     int64
#  13  Mar-23    14 non-null     int64
#  14  Y-O-Y     14 non-null     object
# dtypes: int64(13), object(2)
# memory usage: 1.8+ KB

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      13 non-null     object
#  1   Mar-22    13 non-null     int64
#  2   Apr-22    13 non-null     int64
#  3   May-22    13 non-null     int64
#  4   Jun-22    13 non-null     int64
#  5   Jul-22    13 non-null     int64
#  6   Aug-22    13 non-null     int64
#  7   Sep-22    13 non-null     int64
#  8   Oct-22    13 non-null     int64
#  9   Nov-22    13 non-null     int64
#  10  Dec-22    13 non-null     int64
#  11  Jan-23    13 non-null     int64
#  12  Feb-23    13 non-null     int64
#  13  Mar-23    13 non-null     int64
#  14  Growth %  13 non-null     object
# dtypes: int64(13), object(2)
# memory usage: 1.6+ KB

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  5 non-null      object
#  1   Mar-22      5 non-null      int64
#  2   Apr-22      5 non-null      int64
#  3   May-22      5 non-null      int64
#  4   Jun-22      5 non-null      int64
#  5   Jul-22      5 non-null      int64
#  6   Aug-22      5 non-null      int64
#  7   Sep-22      5 non-null      int64
#  8   Oct-22      5 non-null      int64
#  9   Nov-22      5 non-null      int64
#  10  Dec-22      5 non-null      int64
#  11  Jan-23      5 non-null      int64
#  12  Feb-23      5 non-null      int64
#  13  Mar-23      5 non-null      int64
#  14  Growth %    5 non-null      float64
# dtypes: float64(1), int64(13), object(1)
# memory usage: 728.0+ bytes

# %% [markdown]
# ### 'Drop' function to selectively remove columns, helping to streamline the DataFrames for further analysis and visualization.

# %%
industry.drop(['Mar-22','Y-O-Y'], axis=1, inplace=True)
city.drop(['Mar-22','Growth %'], axis=1, inplace=True)
exp.drop(['Mar-22','Growth %'], axis=1, inplace=True)

# %%
city.head()
# Out:
#           City  Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  Oct-22  \
# 0       Mumbai    2100    2188    2219    2338    2150    2373    1926
# 1  Delhi / NCR    2811    2782    2792    3038    2604    2959    2436
# 2      Chennai    2364    2394    2432    2745    2519    2726    2047
# 3         Pune    4025    4114    4143    5035    4073    4453    3348
# 4      Kolkata    3486    3750    3760    4317    3773    4176    3040
#
#    Nov-22  Dec-22  Jan-23  Feb-23  Mar-23
# 0    2468    2365    2264    2414    2369
# 1    3172    2933    2782    3014    2975
# 2    2625    2337    2207    2558    2478
# 3    4221    3869    3682    4131    3932
# 4    4026    3754    3413    3754    3522

# %% [markdown]
# ### Setting the index, to easily retrieve and analyze data based on the specified index

# %%
industry.set_index('Industry', inplace=True)
city.set_index('City', inplace=True)
exp.set_index('Experience', inplace=True)

# %%
industry.describe()
# Out:
#             Apr-22       May-22      June-22      July-22       Aug-22  \
# count    14.000000    14.000000    14.000000    14.000000    14.000000
# mean   2725.428571  2730.000000  2633.714286  2816.357143  2679.642857
# std    1886.147425  1836.340592  1760.547836  1871.738912  1775.229719
# min     522.000000   517.000000   491.000000   581.000000   550.000000
# 25%    1567.000000  1688.750000  1541.250000  1581.500000  1549.750000
# 50%    2052.000000  2066.500000  2009.000000  2163.500000  2085.500000
# 75%    3340.000000  3269.250000  3230.000000  3613.500000  3528.000000
# max    6323.000000  6403.000000  5983.000000  6402.000000  6546.000000
#
#             Sep-22       Oct-22       Nov-22       Dec-22       Jan-23  \
# count    14.000000    14.000000    14.000000    14.000000    14.000000
# mean   2940.500000  2412.357143  2873.357143  2764.214286  2623.571429
# std    1847.494717  1507.357882  1824.716990  1768.419815  1619.106435
# ...

# %% [markdown]
# - Count: The summary covers 14 industries, each with job count data for the specified months.
# - Mean: On average, the industries had around 2725 job openings in April 2022. This mean count fluctuated over the months, showing variations in job availability across industries.
# - Standard Deviation (Std): The standard deviation values indicate the degree of variability in job counts. Larger values suggest that job counts varied widely across industries for the respective months.
# - Minimum (Min): The lowest job count recorded among the industries was 522 in April 2022. This represents the industry with the fewest job openings for that month.
# - 25th Percentile (25%): For April 2022, 25% of industries had a job count below 1567. This provides insight into the lower range of job availability.
# - Median (50%): In April 2022, the median job count was 2052. This indicates that half of the industries had job counts below this value, and half had counts above.
# - 75th Percentile (75%): For April 2022, 75% of industries had a job count below 3340. This demonstrates the upper range of job availability.
# - Maximum (Max): The highest job count recorded among the industries was 6323 in April 2022. This represents the industry with the most job openings for that month.

# %%
city.describe()
# Out:
#             Apr-22       May-22       Jun-22       Jul-22       Aug-22  \
# count    13.000000    13.000000    13.000000    13.000000    13.000000
# mean   3386.153846  3407.769231  3505.230769  3870.615385  3466.384615
# std     853.678886   842.433593  1014.701775  1125.648964  1037.372847
# min    2100.000000  2188.000000  2077.000000  2014.000000  1962.000000
# 25%    2798.000000  2782.000000  2702.000000  2881.000000  2519.000000
# 50%    3486.000000  3484.000000  3722.000000  4282.000000  3748.000000
# 75%    4097.000000  4114.000000  4143.000000  4578.000000  4073.000000
# max    4527.000000  4596.000000  5478.000000  5344.000000  5110.000000
#
#             Sep-22       Oct-22       Nov-22       Dec-22       Jan-23  \
# count    13.000000    13.000000    13.000000    13.000000    13.000000
# mean   3679.923077  2961.461538  3723.000000  3549.307692  3376.615385
# std    1045.837421   875.625549  1023.435717  1076.216473  1031.852908
# ...

# %% [markdown]
# - Count: The summary covers 13 cities, each with job count data for the specified months.
# - Mean: On average, the cities had around 3386 job openings in April 2022. This mean count fluctuated over the months, indicating variations in job availability across cities.
# - Standard Deviation (Std): The standard deviation values reveal the extent of variability in job counts. Larger values suggest substantial variations in job availability across different cities for the respective months.
# - Minimum (Min): The lowest job count recorded among the cities was 2100 in April 2022. This represents the city with the fewest job openings for that month.
# - 25th Percentile (25%): For April 2022, 25% of cities had a job count below 2798. This offers insight into the lower range of job availability.
# - Median (50%): In April 2022, the median job count was 3486. This indicates that half of the cities had job counts below this value, and half had counts above.
# - 75th Percentile (75%): For April 2022, 75% of cities had a job count below 4097. This demonstrates the upper range of job availability.
# - Maximum (Max): The highest job count recorded among the cities was 4527 in April 2022. This represents the city with the most job openings for that month.

# %%
industry['Total']= industry.sum(axis= 1)
city['Total']= city.sum(axis= 1)
exp['Total']= exp.sum(axis= 1)

# %% [markdown]
# - Total job counts for each industry, city, and experience level

# %%
industry.head(15)
# Out:
#                                          Apr-22  May-22  June-22  July-22  \
# Industry
# Insurance                                  1553    1946     1761     2124
# Banking/Financial Services/Broking         3348    3299     3279     3731
# Oil and Gas/Power/Infrastructure/Energy     522     517      491      581
# Real Estate/ Property                      3316    3180     3083     3261
# Auto/Auto Ancillary                        1146    1152     1106     1183
# FMCG/Foods/Beverage                        1996    1960     1976     2203
# Telecom/ISP                                 607     669      622      741
# Travel & Hospitality                       1609    1603     1468     1487
# Pharma/Biotech/Clinical Research           2108    2078     1908     2081
# Medical/Healthcare/Hospital                6323    6403     5983     6402
# BPO/ITES/CRM/Transcription                 2659    2617     2600     2587
# ...

# %%
city.head(10)
# Out:
#                           Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  \
# City
# Mumbai                      2100    2188    2219    2338    2150    2373
# Delhi / NCR                 2811    2782    2792    3038    2604    2959
# Chennai                     2364    2394    2432    2745    2519    2726
# Pune                        4025    4114    4143    5035    4073    4453
# Kolkata                     3486    3750    3760    4317    3773    4176
# Hyderabad / Secunderabad    4097    3967    3907    4578    3812    4246
# Bengaluru / Bangalore       3532    3484    3722    4076    3420    3671
# Vadodara / Baroda           2798    2872    2702    2881    2512    2901
# Ahmedabad                   4235    4438    4598    5344    5110    5814
# Jaipur                      4435    4206    4272    4282    4632    4730
#
#                           Oct-22  Nov-22  Dec-22  Jan-23  Feb-23  Mar-23  \
# City
# Mumbai                      1926    2468    2365    2264    2414    2369
# ...

# %%
exp.head()
# Out:
#             Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  Oct-22  Nov-22  \
# Experience
# 0-3 yrs       3223    3170    3105    3266    2999    3265    2642    3253
# 4-7 yrs       3067    3067    3072    3386    3053    3346    2632    3293
# 8-12 yrs      2494    2557    2663    3093    2644    2914    2229    2864
# 13-16 yrs     1854    1885    2008    2298    1928    2178    1771    2342
# 16 + yrs      1713    1695    1722    2013    1693    1946    1613    2055
#
#             Dec-22  Jan-23  Feb-23  Mar-23  Total
# Experience
# 0-3 yrs       3106    2926    3073    3144  37172
# 4-7 yrs       2998    2871    3104    3010  36899
# 8-12 yrs      2676    2568    2885    2859  32446
# 13-16 yrs     2231    2159    2362    2389  25405
# 16 + yrs      2184    2051    2273    2373  23331

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')

# %%
industry['Total'].plot(kind='bar', figsize=(10,5))
plt.xlabel('Industry')
plt.title('Industry wise Job creation of 2022')

plt.show()

# %% [markdown]
# - Medical/Healthcare/Hospital: With a substantial total of 81,138 job openings, the medical and healthcare sector exhibited the highest demand for employees. The ongoing emphasis on healthcare services, increased healthcare awareness, and the need for medical professionals contributed to this trend.
# - Education/Teaching/Training: The education and teaching industry displayed a significant demand for talent, contributing to a total of 70,637 job openings. The growth of educational institutions, e-learning platforms, and the requirement for skilled educators influenced job opportunities.
# - IT-Software/Software Services: This sector showcased a strong demand for employees, contributing to a substantial cumulative total of 60,626 job openings. The continuous growth of the IT sector, digital transformation initiatives, and the expansion of software services played a pivotal role in job creation.
# - Banking/Financial Services/Broking: This sector demonstrated a high demand for talent, with a total of 49,517 job openings. The evolution of financial services, the shift towards digital banking, and the requirement for financial experts contributed to sustained employment opportunities.
# - Real Estate/Property: The real estate industry exhibited considerable demand for employees, contributing to a total of 46,979 job openings. Urban development projects, the construction of commercial and residential spaces, and the expansion of the real estate market influenced job creation.

# %%
city['Total'].plot(kind='bar', figsize=(20,10))
plt.xlabel('Industry')
plt.title('City wise Job creation of 2022')

plt.show()

# %% [markdown]
# - Mumbai: Mumbai had a cumulative total of 29,203 job openings during the specified period. The city's status as a financial and business hub, along with its vibrant job market across various sectors, contributed to this significant demand.
# - Delhi / NCR: The Delhi/NCR region showcased the highest demand for employees, with a substantial total of 37,074 job openings. Being India's capital region, it hosts a diverse range of industries, government institutions, and corporate offices, leading to a strong demand for skilled professionals.
# - Chennai: Chennai exhibited a consistent demand for talent, contributing to a total of 31,846 job openings. Known for its IT and manufacturing sectors, Chennai's growing economy and technological advancements played a role in driving job opportunities.
# - Pune: The city of Pune demonstrated a considerable need for employees, presenting a total of 53,038 job openings. Pune's thriving IT sector, educational institutions, and emerging startup ecosystem contributed to the city's strong employment trends.
# - Kolkata: Kolkata displayed strong demand for talent, contributing to a total of 48,344 job openings. As a historical and cultural hub with growing industries like IT, finance, and real estate, Kolkata continued to attract job seekers.
# - Hyderabad / Secunderabad: Hyderabad had a noteworthy demand for employees, presenting a total of 50,520 job openings. The city's reputation as a major IT and business center, along with its proactive government policies, fostered employment growth.
# - Bengaluru / Bangalore: Bengaluru showcased a strong demand for employees, contributing to a total of 44,816 job openings. Known as the Silicon Valley of India, Bengaluru's thriving IT and startup ecosystem led to sustained employment opportunities.
# - Vadodara / Baroda: Vadodara showed consistent demand for talent, with a total of 38,973 job openings. The city's industrial growth, educational institutions, and favorable business environment influenced its employment trends.
# - Ahmedabad: The city of Ahmedabad displayed a substantial need for employees, presenting a total of 67,369 job openings. Ahmedabad's diversified economy, including industries like textiles, pharmaceuticals, and finance, contributed to its robust job market.
# - Jaipur: Jaipur exhibited consistent demand for talent, contributing to a total of 58,231 job openings. As a growing business and tourist destination, Jaipur's expanding retail, hospitality, and education sectors influenced its employment landscape.

# %%
exp['Total'].plot(kind='bar', figsize=(20,10))
plt.xlabel('Experience')
plt.title('Experience wise Job creation of 2022')

plt.show()

# %% [markdown]
# - 0-3 years of experience: This experience level showcased a cumulative total of 40,326 job openings. India's thriving startup ecosystem, expansion of tech-enabled services, and the demand for fresh talent contributed to the significant opportunities for individuals in the early stages of their careers.
# - 4-7 years of experience: With a cumulative total of 39,917 job openings, professionals with 4-7 years of experience were in demand. This experience bracket often includes mid-level roles, contributing to the observed job opportunities.
# - 8-12 years of experience: The experience range of 8-12 years displayed a total of 34,951 job openings. Professionals with this experience level often occupy managerial and senior roles, contributing to the demand.
# - 13-16 years of experience: Individuals with 13-16 years of experience had a cumulative total of 27,327 job openings. This experience group includes seasoned professionals who often occupy senior management positions.
# - 16+ years of experience: This category exhibited a cumulative total of 25,093 job openings. Professionals with over 16 years of experience, often in leadership roles, contributed to the observed demand.

# %%
industry = industry.loc[:, industry.columns != 'Total']
city = city.loc[:, city.columns != 'Total']
exp = exp.loc[:, exp.columns != 'Total']

# %%
bfsi= industry.loc['Banking/Financial Services/Broking']
insurance.head()
# Out:
# Apr-22     1553
# May-22     1946
# June-22    1761
# July-22    2124
# Aug-22     2200
# Name: Insurance, dtype: int64

# %%
bfsi.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# - In March 2023, India's BFSI sector witnessed an exceptional surge in job openings, marking a record-breaking trend. The insurance domain achieved a remarkable 108% YoY growth, driven by insurance product sales roles, while the banking sector saw a 45% YoY expansion due to the rapid adoption of digital banking services. This trend aligns with recent news, highlighting the sector's pivotal role in boosting India's economic recovery.

# %%
top_5_industry= industry.head()

# %%
top_5_industry = top_5_industry.transpose()
top_5_industry.head()
# Out:
# Industry  Insurance  Banking/Financial Services/Broking  \
# Apr-22         1553                                3348
# May-22         1946                                3299
# June-22        1761                                3279
# July-22        2124                                3731
# Aug-22         2200                                3576
#
# Industry  Oil and Gas/Power/Infrastructure/Energy  Real Estate/ Property  \
# Apr-22                                        522                   3316
# May-22                                        517                   3180
# June-22                                       491                   3083
# July-22                                       581                   3261
# Aug-22                                        550                   3384
#
# Industry  Auto/Auto Ancillary
# Apr-22                   1146
# May-22                   1152
# June-22                  1106
# July-22                  1183
# Aug-22                   1360

# %%
top_5_industry.plot(kind='line',
             stacked=False,
             figsize=(20, 10)) 

plt.title('Top 5 Industries in terms of Employment')
plt.ylabel('Jobs Created')
plt.xlabel('Month')

plt.show()

# %% [markdown]
# - Insurance Industry: The insurance sector saw moderate job openings in April, gradually climbing to peak at 2544 in December 2022, with some fluctuations in between.
# - Banking/Financial Services/Broking: This sector exhibited varying job openings, with the highest at 4496 in September 2022 and a noticeable spike in November 2022.
# - Oil and Gas/Power/Infrastructure/Energy: Job opportunities remained relatively consistent throughout the period, with occasional fluctuations.
# - Real Estate/Property: The real estate sector showed moderate job openings without drastic fluctuations, peaking at 4507 in September 2022.
# - Auto/Auto Ancillary: The auto industry exhibited an upward trend in job openings, reaching its highest at 1360 in August 2022, then remaining steady.
#
# The detailed analysis indicates dynamic trends within each industry. Some sectors experienced consistent growth, while others displayed periodic fluctuations in job opportunities. These insights shed light on the employment dynamics in these industries during the specified timeframe.

# %%
city.sort_values(by='Total', ascending=False, inplace=True)

#Top Cities
city_Des = city['Total'].tail(15)
city_Des
# Out:
# City
# Ahmedabad                     63328
# Ernakulam / Kochi / Cochin    55782
# Jaipur                        54400
# Pune                          49026
# Hyderabad / Secunderabad      46402
# Kolkata                       44771
# Coimbatore                    42076
# Bengaluru / Bangalore         41115
# Vadodara / Baroda             36457
# Delhi / NCR                   34298
# Chennai                       29432
# Mumbai                        27174
# Chandigarh                    25108
# Name: Total, dtype: int64

# %%
city_Des.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Jobs')
plt.title('Top Cities Contributing to the Employment')

for index, value in enumerate(city_top15): 
    label = format(int(value), ',') 
    
plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')

plt.show()

# %% [markdown]
# - Ahmedabad: Leading the pack with 63,328 job vacancies, Ahmedabad showcases robust employment prospects. Its growth might be attributed to its emerging IT sector, along with growth in other industries.
#
# - Ernakulam / Kochi / Cochin: This region follows closely with 55,782 vacancies, indicating a thriving job market. The presence of technology parks, finance, and trade centers could be contributing factors.
#
# - Jaipur: With 54,400 job vacancies, Jaipur demonstrates considerable growth. The city's development as an education hub and rising entrepreneurship could be driving employment opportunities.
#
# - Pune: Known for its IT and manufacturing sectors, Pune offers 49,026 vacancies. Its established business ecosystem and educational institutions contribute to its job market strength.
#
# - Hyderabad / Secunderabad: The city has 46,402 job vacancies, reflecting its prominence in IT, pharmaceuticals, and services sectors. Hyderabad's growth as a technology and business hub is a key driver.

# %%
explode_list = [0.0, 0, 0.1, 0.1, 0.2] 
exp['Total'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,                 
                            pctdistance=1.12,           
                            explode=explode_list         
                            )

plt.title('HIRING TRENDS ACROSS EXPERIENCE LEVELS', y=1.12) 
plt.axis('equal') 

plt.legend(labels=exp.index, loc='upper left') 

plt.show()

# %% [markdown]
# - Industry Trends:
#
# The Insurance and Banking sectors witnessed substantial job creation, attributed to a remarkable 108% YoY growth in the insurance sector and a 45% YoY growth in the banking sector. The expansion of digital banking services fueled growth.
# Other industries, such as Real Estate, FMCG, Education, and Healthcare, also demonstrated notable growth, contributing to a diversified employment landscape.
# However, certain industries, including IT and Retail, experienced slower job creation due to various factors.
#
# - City-wise Trends:
#
# Mumbai, Delhi/NCR, and Chennai exhibited consistent job growth across the reported period.
# Pune, although experiencing growth, showed a decline in October, potentially influenced by factors like festivals or regional events.
# Vadodara, Ahmedabad, and Jaipur displayed remarkable growth in terms of job vacancies, reflecting positive regional economic dynamics.
#
# - Experience Level Trends:
#
# The analysis of job trends based on experience levels highlighted consistent growth across most categories.
# Entry-level (0-3 yrs) and mid-level (4-7 yrs) job segments exhibited stable job creation.
# Professionals with experience ranging from 8-16+ years saw consistent growth in job opportunities.
